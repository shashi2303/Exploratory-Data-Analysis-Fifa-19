# %%
#import libraries
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\KIIT'

# %%
data = pd.read_csv(r"C:\Users\KIIT\Desktop\data anylisis\fifadataset.csv")

# %%
#shape of dataset
print(data.shape)
# Out:
# (18207, 89)

# %%
#Name of columns
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#sort the top 15 players on the basis of their value and wage
#To view the distribution of data(age,overall)

# %%
from matplotlib import pyplot as plt

# %%
plt.title('Distribution of age')
plt.figure(figsize=[10,7])
plt.hist(data['Age'])
# Out:
# (array([1.063e+03, 3.687e+03, 4.030e+03, 3.868e+03, 2.977e+03, 1.689e+03,
#         7.270e+02, 1.440e+02, 1.900e+01, 3.000e+00]),
#  array([16. , 18.9, 21.8, 24.7, 27.6, 30.5, 33.4, 36.3, 39.2, 42.1, 45. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=[10,7])
plt.hist(data['Overall'])
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
data['Overall'].mean()
# Out:
# 66.23869940132916

# %%
data['Nationality'].value_counts().head(50).plot(kind='bar',figsize=[20,20])

# %%
#data cleaning ,to perform data cleaning copying data to football.
football=data.copy()

# %%
#To convert String data of 'value' and 'wages' columns to float value
def str2float(euros):
    #converting M in value columns to  millions
    if euros[-1] =='M':
        return float(euros[1:-1])*1000000
    elif euros[-1] == 'K':
        return float(euros[1:-1])*1000
    else:
        return float(euros[1:])
#use lambda function to apply UFD str2float()for each players market value
football['Value']=football['Value'].apply(lambda x: str2float(x))
#using lambda function to apply UFD  str2float() for each players current wage
football['Wage']=football['Wage'].apply(lambda x: str2float(x))

# %%
#to see football dataset after copying and changing wage and value columns
football.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
#Ro see only Name a,value and wage columns after converting
football[['Name','Value','Wage']]
# Out:
#                        Name        Value      Wage
# 0                  L. Messi  110500000.0  565000.0
# 1         Cristiano Ronaldo   77000000.0  405000.0
# 2                 Neymar Jr  118500000.0  290000.0
# 3                    De Gea   72000000.0  260000.0
# 4              K. De Bruyne  102000000.0  355000.0
# 5                 E. Hazard   93000000.0  340000.0
# 6                 L. Modrić   67000000.0  420000.0
# 7                 L. Suárez   80000000.0  455000.0
# 8              Sergio Ramos   51000000.0  380000.0
# 9                  J. Oblak   68000000.0   94000.0
# 10           R. Lewandowski   77000000.0  205000.0
# 11                 T. Kroos   76500000.0  355000.0
# 12                 D. Godín   44000000.0  125000.0
# 13              David Silva   60000000.0  285000.0
# 14                 N. Kanté   63000000.0  225000.0
# 15                P. Dybala   89000000.0  205000.0
# 16                  H. Kane   83500000.0  205000.0
# ...

# %%
plt.hist(football['Value'])
# Out:
# (array([1.7495e+04, 4.8400e+02, 1.3300e+02, 4.5000e+01, 1.8000e+01,
#         1.7000e+01, 9.0000e+00, 3.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([0.0000e+00, 1.1850e+07, 2.3700e+07, 3.5550e+07, 4.7400e+07,
#         5.9250e+07, 7.1100e+07, 8.2950e+07, 9.4800e+07, 1.0665e+08,
#         1.1850e+08]),
#  <a list of 10 Patch objects>)

# %%
#finding missing value in value column
football['Value'].isnull().sum()
# Out:
# 0

# %%
plt.hist(football['Wage'])
# Out:
# (array([1.7745e+04, 3.0500e+02, 9.3000e+01, 3.4000e+01, 1.2000e+01,
#         8.0000e+00, 6.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([     0.,  56500., 113000., 169500., 226000., 282500., 339000.,
#         395500., 452000., 508500., 565000.]),
#  <a list of 10 Patch objects>)

# %%
#helps in plotting distribution plot
import seaborn as sns

# %%
sns.distplot(football['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(football['Value'])

# %%
#Sorting the top 15 players according to their value
football.sort_values(by='Value',ascending=False)[['Name','Value','Wage']].head(15)
# Out:
#                  Name        Value      Wage
# 2           Neymar Jr  118500000.0  290000.0
# 0            L. Messi  110500000.0  565000.0
# 4        K. De Bruyne  102000000.0  355000.0
# 5           E. Hazard   93000000.0  340000.0
# 15          P. Dybala   89000000.0  205000.0
# 16            H. Kane   83500000.0  205000.0
# 25          K. Mbappé   81000000.0  100000.0
# 7           L. Suárez   80000000.0  455000.0
# 17       A. Griezmann   78000000.0  145000.0
# 10     R. Lewandowski   77000000.0  205000.0
# 1   Cristiano Ronaldo   77000000.0  405000.0
# 11           T. Kroos   76500000.0  355000.0
# 30               Isco   73500000.0  315000.0
# 31         C. Eriksen   73500000.0  205000.0
# 3              De Gea   72000000.0  260000.0

# %%
#top 15 players based on their wage
football.sort_values(by='Wage',ascending=False)[['Name','Value','Wage']].head(15)
# Out:
#                  Name        Value      Wage
# 0            L. Messi  110500000.0  565000.0
# 7           L. Suárez   80000000.0  455000.0
# 6           L. Modrić   67000000.0  420000.0
# 1   Cristiano Ronaldo   77000000.0  405000.0
# 8        Sergio Ramos   51000000.0  380000.0
# 11           T. Kroos   76500000.0  355000.0
# 36            G. Bale   60000000.0  355000.0
# 4        K. De Bruyne  102000000.0  355000.0
# 5           E. Hazard   93000000.0  340000.0
# 32           Coutinho   69500000.0  340000.0
# 30               Isco   73500000.0  315000.0
# 28       J. Rodríguez   69500000.0  315000.0
# 20    Sergio Busquets   51500000.0  315000.0
# 23          S. Agüero   64500000.0  300000.0
# 2           Neymar Jr  118500000.0  290000.0

# %% [markdown]
# football.describe()

# %%
#for stasticaldescribe() is used to view some basic statistical details like count, mean, std ,min etc
football.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#               Value           Wage       Special  International Reputation  \
# count  1.820700e+04   18207.000000  18207.000000              18159.000000
# mean   2.410696e+06    9731.312133   1597.809908                  1.113222
# ...

# %%
# This will give us the colums-wise sum of the missing values
data.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
# Filling the missing value for the continous variables for proper data visualization

data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %%
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
data.fillna(0,inplace=True)

# %%
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
# Visuals of the most prefered foot of the top 50 players

ax=data['Preferred Foot'].value_counts().plot.bar(color = 'yellow')
ax.set_title('Most Preferred Foot of the Players', fontsize = 20)
ax.set_xlabel('right or left',size=20,color='red')
ax.set_ylabel('count of players',size=20,color='red')
# Out:
# Text(0, 0.5, 'count of players')

# %%
# different positions acquired by the players 

plt.figure(figsize = (12, 8))
sns.set(style = 'darkgrid', palette = 'colorblind',color_codes = True)
ax = sns.countplot('Position', data = data)
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 20)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 20)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()

# %%
# Height of Players

plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'Height', data = data, palette = 'dark')
ax.set_title(label = 'Count of players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height in Foot per inch', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %%
ax=data['Nationality'].value_counts().plot.bar(color = 'yellow')
ax.set_title('countries with highest overall score', fontsize = 20)
ax.set_xlabel('country',size=20,color='red')
ax.set_ylabel('count',size=20,color='red')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(12, 8))
plt.title("Number of Players by position")
fig = sns.countplot(x = 'Position', data =data)

# %%
#Player Count on the basis of Height
plt.figure(figsize=(12, 8))
plt.title("Number of Players by Height")
fig = sns.countplot(x = 'Height', data =data)

# %%
#Player Count on the basis of Weight
ax=data['Weight'].value_counts().plot.bar(color = 'blue',figsize=[20,20])
ax.set_title('Number of players by weight', fontsize = 20)
ax.set_xlabel('Weight',size=40,color='red')
ax.set_ylabel('counts',size=40,color='red')
# Out:
# Text(0, 0.5, 'counts')

# %%
#Player Count on the basis of Age
ax=data['Age'].value_counts().plot.bar(color = 'brown',figsize=[20,20])
ax.set_title('Number of players by Age', fontsize = 20)
ax.set_xlabel('age',size=40,color='red')
ax.set_ylabel('counts',size=40,color='red')
# Out:
# Text(0, 0.5, 'counts')

# %%
ax=data['Nationality'].value_counts().plot.bar(color = 'yellow',figsize=[40,40])
ax.set_title('countries with hihest overall score', fontsize = 20)
ax.set_xlabel('countires',size=20,color='red')
ax.set_ylabel('count',size=20,color='red')
# Out:
# Text(0, 0.5, 'count')

# %%
#Age Vs Overall
import matplotlib.pyplot as plt
data.plot(x='Age',y="Overall",kind='hist')
plt.xlabel("Age")
plt.ylabel("Overall")
plt.show()

# %%
#Age Vs potential
import matplotlib.pyplot as plt
data.plot(x='Age',y="Potential",kind='hist')
plt.xlabel("Age")
plt.ylabel("Potential")
plt.show()

# %%
import matplotlib.pyplot as plt
ax=data.plot(x="Age",y="Overall",kind="line")
ax.set_ylabel(ylabel = 'overall', fontsize = 16)
plt.show()

# %%
#Value and Wage of a Player according to Age
plt.figure(figsize=(40,40))
fig=sns.scatterplot(x="Value",y="Wage",hue="Age",data=data)
plt.show()

# %%
#Maximum Value of a Player according to Age
sns.scatterplot(x="Age", y="Value", data=data)

# %%
#Highest Earning Player

ax=data['Wage'].value_counts().plot.bar(color = 'brown',figsize=[40,40])
ax.set_title('Number of players by Age', fontsize = 20)
ax.set_xlabel('age',size=40,color='red')
ax.set_ylabel('counts',size=40,color='red')
# Out:
# Text(0, 0.5, 'counts')
